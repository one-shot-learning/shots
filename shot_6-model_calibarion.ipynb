# %%
# !kaggle datasets download -d saddamazyazy/go-to-college-dataset

# %%
# !unzip go-to-college-dataset.zip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context('talk')

from sklearn.preprocessing import OrdinalEncoder
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, export_text
from sklearn.metrics import classification_report

# %%
df = pd.read_csv('data.csv')

# %%
df
# Out:
#     type_school school_accreditation  gender         interest residence  \
# 0      Academic                    A    Male  Less Interested     Urban
# 1      Academic                    A    Male  Less Interested     Urban
# 2      Academic                    B  Female  Very Interested     Urban
# 3    Vocational                    B    Male  Very Interested     Rural
# 4      Academic                    A  Female  Very Interested     Urban
# ..          ...                  ...     ...              ...       ...
# 995  Vocational                    A  Female  Very Interested     Rural
# 996    Academic                    B  Female  Less Interested     Rural
# 997  Vocational                    A    Male  Less Interested     Urban
# 998    Academic                    B    Male        Uncertain     Rural
# 999    Academic                    B    Male       Interested     Urban
#
#      parent_age  parent_salary  house_area  average_grades  \
# 0            56        6950000        83.0           84.09
# 1            57        4410000        76.8           86.91
# 2            50        6500000        80.6           87.43
# 3            49        6600000        78.2           82.12
# 4            57        5250000        75.1           86.79
# ..          ...            ...         ...             ...
# 995          49        7420000        63.6           85.99
# 996          51        7480000        84.3           89.72
# 997          49        5550000        75.2           79.56
# 998          53        5840000       105.8           87.18
# 999          50        2940000        69.1           86.13
#
#      parent_was_in_college  will_go_to_college
# 0                    False                True
# 1                    False                True
# 2                    False                True
# 3                     True                True
# 4                    False               False
# ..                     ...                 ...
# 995                   True                True
# 996                   True                True
# 997                  False                True
# 998                   True                True
# 999                   True               False
#
# [1000 rows x 11 columns]

# %%
df.isna().sum()
# Out:
# type_school              0
# school_accreditation     0
# gender                   0
# interest                 0
# residence                0
# parent_age               0
# parent_salary            0
# house_area               0
# average_grades           0
# parent_was_in_college    0
# will_go_to_college       0
# dtype: int64

# %%
df_str = df.select_dtypes(include='object')
df_str
# Out:
#     type_school school_accreditation  gender         interest residence
# 0      Academic                    A    Male  Less Interested     Urban
# 1      Academic                    A    Male  Less Interested     Urban
# 2      Academic                    B  Female  Very Interested     Urban
# 3    Vocational                    B    Male  Very Interested     Rural
# 4      Academic                    A  Female  Very Interested     Urban
# ..          ...                  ...     ...              ...       ...
# 995  Vocational                    A  Female  Very Interested     Rural
# 996    Academic                    B  Female  Less Interested     Rural
# 997  Vocational                    A    Male  Less Interested     Urban
# 998    Academic                    B    Male        Uncertain     Rural
# 999    Academic                    B    Male       Interested     Urban
#
# [1000 rows x 5 columns]

# %%
for col in df_str.columns:
    print(col, df_str[col].unique())
# Out:
# type_school ['Academic' 'Vocational']
# school_accreditation ['A' 'B']
# gender ['Male' 'Female']
# interest ['Less Interested' 'Very Interested' 'Uncertain' 'Not Interested'
#  'Interested']
# residence ['Urban' 'Rural']

# %%
def preprocess(df):
    df_str = df.select_dtypes(include='object')
    enc = OrdinalEncoder(categories=[
        df_str[col].unique() if col != 'interest' else [
            'Not Interested', 'Less Interested', 'Uncertain', 'Interested', 'Very Interested']
        for col in df_str.columns
    ])
    df = pd.concat([
        pd.DataFrame(enc.fit_transform(df_str), columns=df_str.columns, index=df_str.index),
        df.select_dtypes(exclude='object')
    ], axis=1)
    
    return df.drop(columns=['will_go_to_college']), df['will_go_to_college']

# %% [markdown]
# # One model to rule them all!

# %%
np.random.seed(13)

train, test = train_test_split(df, test_size=0.3)

train_x, train_y = preprocess(train)
test_x, test_y = preprocess(test)

# %%
model = DecisionTreeClassifier()

model.fit(train_x, train_y)
print(classification_report(model.predict(test_x), test_y))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.71      0.76      0.73       140
#         True       0.77      0.72      0.75       160
#
#     accuracy                           0.74       300
#    macro avg       0.74      0.74      0.74       300
# weighted avg       0.74      0.74      0.74       300

# %%
sorted(list(zip(train.columns, model.feature_importances_)),
       key=lambda x: x[1],
       reverse=True)
# Out:
# [('average_grades', 0.4230893191101725),
#  ('parent_salary', 0.20172634884632726),
#  ('house_area', 0.17037989602130768),
#  ('residence', 0.05032889563955828),
#  ('interest', 0.039254216832914204),
#  ('school_accreditation', 0.028831115054717533),
#  ('parent_was_in_college', 0.02808403361344538),
#  ('parent_age', 0.027668593672161897),
#  ('type_school', 0.02682805739987149),
#  ('gender', 0.0038095238095238095)]

# %%
fig, axes = plt.subplots(ncols=3, figsize=(15, 5))

for cur_ax, feature in zip(axes, ['average_grades', 'parent_salary', 'house_area']):
    sns.histplot(train[train['residence'] == 'Rural'][feature],
                color='green',
                 label='Rural',
                 element='step',
                 kde=True,
                 ax=cur_ax)
    sns.histplot(train[train['residence'] == 'Urban'][feature],
                color='gray',
                 label='Urban',
                 element='step',
                 kde=True,
                 ax=cur_ax)
    
    cur_ax.set_title(feature)
    cur_ax.legend()
    
fig.tight_layout()
fig.show()
# Out:
# /var/folders/3t/tc9ht2z16psg1c40dl47_pmm0000gn/T/ipykernel_5785/2106700058.py:21: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig, axes = plt.subplots(nrows=3, figsize=(10, 10), sharex=True)

for cur_ax, residence_values in zip(axes, [{'Rural'}, {'Urban'}, {'Rural', 'Urban'}]):
    subset = train[train['residence'].isin(residence_values)]
    sns.histplot(subset[subset['will_go_to_college']]['parent_salary'],
                color='limegreen',
                 label='True',
                 element='step',
                 kde=True,
                 ax=cur_ax)
    sns.histplot(subset[~subset['will_go_to_college']]['parent_salary'],
                color='tomato',
                 label='True',
                 element='step',
                 kde=True,
                 ax=cur_ax)
    
    threshold = (
        DecisionTreeClassifier(max_depth=1)
        .fit(subset[['parent_salary']], subset['will_go_to_college'])
        .tree_.threshold[0]
    )
    cur_ax.axvline(threshold, color='orange')
    cur_ax.set_title(residence_values)
    cur_ax.legend()
    
fig.tight_layout()
fig.show()
# Out:
# /var/folders/3t/tc9ht2z16psg1c40dl47_pmm0000gn/T/ipykernel_5785/3530681189.py:28: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
print(export_text(model, feature_names=list(train_x.columns)))
# Out:
# |--- average_grades <= 86.81
# |   |--- parent_salary <= 4665000.00
# |   |   |--- average_grades <= 78.88
# |   |   |   |--- house_area <= 53.90
# |   |   |   |   |--- class: False
# |   |   |   |--- house_area >  53.90
# |   |   |   |   |--- class: True
# |   |   |--- average_grades >  78.88
# |   |   |   |--- house_area <= 77.60
# |   |   |   |   |--- house_area <= 44.40
# |   |   |   |   |   |--- parent_age <= 54.00
# |   |   |   |   |   |   |--- class: False
# |   |   |   |   |   |--- parent_age >  54.00
# |   |   |   |   |   |   |--- class: True
# |   |   |   |   |--- house_area >  44.40
# |   |   |   |   |   |--- average_grades <= 81.82
# |   |   |   |   |   |   |--- average_grades <= 81.75
# |   |   |   |   |   |   |   |--- class: False
# |   |   |   |   |   |   |--- average_grades >  81.75
# |   |   |   |   |   |   |   |--- class: True
# |   |   |   |   |   |--- average_grades >  81.82
# |   |   |   |   |   |   |--- class: False
# |   |   |   |--- house_area >  77.60
# |   |   |   |   |--- parent_was_in_college <= 0.50
# |   |   |   |   |   |--- parent_salary <= 3530000.00
# |   |   |   |   |   |   |--- class: False
# |   |   |   |   |   |--- parent_salary >  3530000.00
# |   |   |   |   |   |   |--- residence <= 0.50
# |   |   |   |   |   |   |   |--- class: True
# |   |   |   |   |   |   |--- residence >  0.50
# |   |   |   |   |   |   |   |--- class: False
# |   |   |   |   |--- parent_was_in_college >  0.50
# |   |   |   |   |   |--- class: False
# |   |--- parent_salary >  4665000.00
# |   |   |--- house_area <= 83.35
# |   |   |   |--- residence <= 0.50
# |   |   |   |   |--- house_area <= 61.70
# |   |   |   |   |   |--- average_grades <= 83.82
# |   |   |   |   |   |   |--- class: False
# |   |   |   |   |   |--- average_grades >  83.82
# |   |   |   |   |   |   |--- parent_salary <= 5425000.00
# |   |   |   |   |   |   |   |--- class: False
# |   |   |   |   |   |   |--- parent_salary >  5425000.00
# |   |   |   |   |   |   |   |--- interest <= 2.50
# |   |   |   |   |   |   |   |   |--- class: True
# |   |   |   |   |   |   |   |--- interest >  2.50
# |   |   |   |   |   |   |   |   |--- average_grades <= 84.87
# |   |   |   |   |   |   |   |   |   |--- class: False
# |   |   |   |   |   |   |   |   |--- average_grades >  84.87
# |   |   |   |   |   |   |   |   |   |--- type_school <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: False
# |   |   |   |   |   |   |   |   |   |--- type_school >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: True
# |   |   |   |   |--- house_area >  61.70
# |   |   |   |   |   |--- type_school <= 0.50
# |   |   |   |   |   |   |--- average_grades <= 85.56
# |   |   |   |   |   |   |   |--- parent_salary <= 5080000.00
# |   |   |   |   |   |   |   |   |--- class: True
# |   |   |   |   |   |   |   |--- parent_salary >  5080000.00
# |   |   |   |   |   |   |   |   |--- parent_salary <= 6055000.00
# |   |   |   |   |   |   |   |   |   |--- parent_was_in_college <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- interest <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: True
# |   |   |   |   |   |   |   |   |   |   |--- interest >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: False
# |   |   |   |   |   |   |   |   |   |--- parent_was_in_college >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: True
# |   |   |   |   |   |   |   |   |--- parent_salary >  6055000.00
# |   |   |   |   |   |   |   |   |   |--- parent_age <= 54.50
# |   |   |   |   |   |   |   |   |   |   |--- interest <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- interest >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: True
# |   |   |   |   |   |   |   |   |   |--- parent_age >  54.50
# |   |   |   |   |   |   |   |   |   |   |--- interest <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: True
# |   |   |   |   |   |   |   |   |   |   |--- interest >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: False
# |   |   |   |   |   |   |--- average_grades >  85.56
# |   |   |   |   |   |   |   |--- class: True
# |   |   |   |   |   |--- type_school >  0.50
# |   |   |   |   |   |   |--- house_area <= 73.90
# |   |   |   |   |   |   |   |--- parent_salary <= 4765000.00
# |   |   |   |   |   |   |   |   |--- class: False
# |   |   |   |   |   |   |   |--- parent_salary >  4765000.00
# |   |   |   |   |   |   |   |   |--- house_area <= 72.50
# |   |   |   |   |   |   |   |   |   |--- parent_salary <= 6055000.00
# |   |   |   |   |   |   |   |   |   |   |--- class: True
# |   |   |   |   |   |   |   |   |   |--- parent_salary >  6055000.00
# |   |   |   |   |   |   |   |   |   |   |--- parent_salary <= 6250000.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: False
# |   |   |   |   |   |   |   |   |   |   |--- parent_salary >  6250000.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: True
# |   |   |   |   |   |   |   |   |--- house_area >  72.50
# |   |   |   |   |   |   |   |   |   |--- class: False
# |   |   |   |   |   |   |--- house_area >  73.90
# |   |   |   |   |   |   |   |--- class: True
# |   |   |   |--- residence >  0.50
# |   |   |   |   |--- parent_salary <= 6305000.00
# |   |   |   |   |   |--- average_grades <= 82.06
# |   |   |   |   |   |   |--- average_grades <= 81.72
# |   |   |   |   |   |   |   |--- class: False
# |   |   |   |   |   |   |--- average_grades >  81.72
# |   |   |   |   |   |   |   |--- class: True
# |   |   |   |   |   |--- average_grades >  82.06
# |   |   |   |   |   |   |--- class: False
# |   |   |   |   |--- parent_salary >  6305000.00
# |   |   |   |   |   |--- average_grades <= 84.32
# |   |   |   |   |   |   |--- interest <= 0.50
# |   |   |   |   |   |   |   |--- parent_salary <= 6615000.00
# |   |   |   |   |   |   |   |   |--- class: False
# |   |   |   |   |   |   |   |--- parent_salary >  6615000.00
# |   |   |   |   |   |   |   |   |--- class: True
# |   |   |   |   |   |   |--- interest >  0.50
# |   |   |   |   |   |   |   |--- class: False
# |   |   |   |   |   |--- average_grades >  84.32
# |   |   |   |   |   |   |--- parent_age <= 48.50
# |   |   |   |   |   |   |   |--- average_grades <= 84.55
# |   |   |   |   |   |   |   |   |--- class: True
# |   |   |   |   |   |   |   |--- average_grades >  84.55
# |   |   |   |   |   |   |   |   |--- average_grades <= 86.27
# |   |   |   |   |   |   |   |   |   |--- class: False
# |   |   |   |   |   |   |   |   |--- average_grades >  86.27
# |   |   |   |   |   |   |   |   |   |--- school_accreditation <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: True
# |   |   |   |   |   |   |   |   |   |--- school_accreditation >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: False
# |   |   |   |   |   |   |--- parent_age >  48.50
# |   |   |   |   |   |   |   |--- house_area <= 72.00
# |   |   |   |   |   |   |   |   |--- class: True
# |   |   |   |   |   |   |   |--- house_area >  72.00
# |   |   |   |   |   |   |   |   |--- average_grades <= 86.09
# |   |   |   |   |   |   |   |   |   |--- class: False
# |   |   |   |   |   |   |   |   |--- average_grades >  86.09
# |   |   |   |   |   |   |   |   |   |--- average_grades <= 86.62
# |   |   |   |   |   |   |   |   |   |   |--- class: True
# |   |   |   |   |   |   |   |   |   |--- average_grades >  86.62
# |   |   |   |   |   |   |   |   |   |   |--- class: False
# |   |   |--- house_area >  83.35
# |   |   |   |--- parent_salary <= 5545000.00
# |   |   |   |   |--- house_area <= 95.85
# |   |   |   |   |   |--- interest <= 0.50
# |   |   |   |   |   |   |--- class: True
# |   |   |   |   |   |--- interest >  0.50
# |   |   |   |   |   |   |--- residence <= 0.50
# |   |   |   |   |   |   |   |--- parent_was_in_college <= 0.50
# |   |   |   |   |   |   |   |   |--- type_school <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: False
# |   |   |   |   |   |   |   |   |--- type_school >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: True
# |   |   |   |   |   |   |   |--- parent_was_in_college >  0.50
# |   |   |   |   |   |   |   |   |--- class: True
# |   |   |   |   |   |   |--- residence >  0.50
# |   |   |   |   |   |   |   |--- class: False
# |   |   |   |   |--- house_area >  95.85
# |   |   |   |   |   |--- parent_age <= 51.00
# |   |   |   |   |   |   |--- house_area <= 105.00
# |   |   |   |   |   |   |   |--- class: False
# |   |   |   |   |   |   |--- house_area >  105.00
# |   |   |   |   |   |   |   |--- class: True
# |   |   |   |   |   |--- parent_age >  51.00
# |   |   |   |   |   |   |--- class: True
# |   |   |   |--- parent_salary >  5545000.00
# |   |   |   |   |--- average_grades <= 86.10
# |   |   |   |   |   |--- class: True
# |   |   |   |   |--- average_grades >  86.10
# |   |   |   |   |   |--- residence <= 0.50
# |   |   |   |   |   |   |--- class: True
# |   |   |   |   |   |--- residence >  0.50
# |   |   |   |   |   |   |--- house_area <= 87.65
# |   |   |   |   |   |   |   |--- class: False
# |   |   |   |   |   |   |--- house_area >  87.65
# |   |   |   |   |   |   |   |--- average_grades <= 86.46
# |   |   |   |   |   |   |   |   |--- class: False
# |   |   |   |   |   |   |   |--- average_grades >  86.46
# |   |   |   |   |   |   |   |   |--- class: True
# |--- average_grades >  86.81
# |   |--- average_grades <= 89.27
# |   |   |--- parent_salary <= 5305000.00
# |   |   |   |--- house_area <= 84.40
# |   |   |   |   |--- average_grades <= 86.93
# |   |   |   |   |   |--- class: True
# |   |   |   |   |--- average_grades >  86.93
# |   |   |   |   |   |--- parent_salary <= 5030000.00
# |   |   |   |   |   |   |--- class: False
# |   |   |   |   |   |--- parent_salary >  5030000.00
# |   |   |   |   |   |   |--- parent_salary <= 5050000.00
# |   |   |   |   |   |   |   |--- class: True
# |   |   |   |   |   |   |--- parent_salary >  5050000.00
# |   |   |   |   |   |   |   |--- class: False
# |   |   |   |--- house_area >  84.40
# |   |   |   |   |--- school_accreditation <= 0.50
# |   |   |   |   |   |--- class: True
# |   |   |   |   |--- school_accreditation >  0.50
# |   |   |   |   |   |--- class: False
# |   |   |--- parent_salary >  5305000.00
# |   |   |   |--- type_school <= 0.50
# |   |   |   |   |--- class: True
# |   |   |   |--- type_school >  0.50
# |   |   |   |   |--- school_accreditation <= 0.50
# |   |   |   |   |   |--- parent_salary <= 5590000.00
# |   |   |   |   |   |   |--- gender <= 0.50
# |   |   |   |   |   |   |   |--- class: True
# |   |   |   |   |   |   |--- gender >  0.50
# |   |   |   |   |   |   |   |--- class: False
# |   |   |   |   |   |--- parent_salary >  5590000.00
# |   |   |   |   |   |   |--- class: True
# |   |   |   |   |--- school_accreditation >  0.50
# |   |   |   |   |   |--- interest <= 2.50
# |   |   |   |   |   |   |--- parent_age <= 52.50
# |   |   |   |   |   |   |   |--- parent_age <= 49.50
# |   |   |   |   |   |   |   |   |--- interest <= 1.50
# |   |   |   |   |   |   |   |   |   |--- class: True
# |   |   |   |   |   |   |   |   |--- interest >  1.50
# |   |   |   |   |   |   |   |   |   |--- average_grades <= 88.47
# |   |   |   |   |   |   |   |   |   |   |--- class: False
# |   |   |   |   |   |   |   |   |   |--- average_grades >  88.47
# |   |   |   |   |   |   |   |   |   |   |--- class: True
# |   |   |   |   |   |   |   |--- parent_age >  49.50
# |   |   |   |   |   |   |   |   |--- average_grades <= 87.30
# |   |   |   |   |   |   |   |   |   |--- parent_salary <= 6595000.00
# |   |   |   |   |   |   |   |   |   |   |--- class: True
# |   |   |   |   |   |   |   |   |   |--- parent_salary >  6595000.00
# |   |   |   |   |   |   |   |   |   |   |--- class: False
# |   |   |   |   |   |   |   |   |--- average_grades >  87.30
# |   |   |   |   |   |   |   |   |   |--- class: False
# |   |   |   |   |   |   |--- parent_age >  52.50
# |   |   |   |   |   |   |   |--- class: True
# |   |   |   |   |   |--- interest >  2.50
# |   |   |   |   |   |   |--- class: True
# |   |--- average_grades >  89.27
# |   |   |--- parent_age <= 47.50
# |   |   |   |--- house_area <= 85.45
# |   |   |   |   |--- class: True
# |   |   |   |--- house_area >  85.45
# |   |   |   |   |--- school_accreditation <= 0.50
# |   |   |   |   |   |--- class: True
# |   |   |   |   |--- school_accreditation >  0.50
# |   |   |   |   |   |--- class: False
# |   |   |--- parent_age >  47.50
# |   |   |   |--- class: True

# %% [markdown]
# # Two models to rule them all!

# %%
for residence_value in ['Rural', 'Urban']:
    train_x, train_y = preprocess(train[train['residence'] == residence_value])
    test_x, test_y = preprocess(test[test['residence'] == residence_value])
    
    model = DecisionTreeClassifier().fit(train_x, train_y)
    print(residence_value)
    print(classification_report(model.predict(test_x), test_y))
# Out:
# Rural
#               precision    recall  f1-score   support
#
#        False       0.77      0.89      0.83        57
#         True       0.92      0.82      0.87        85
#
#     accuracy                           0.85       142
#    macro avg       0.85      0.86      0.85       142
# weighted avg       0.86      0.85      0.85       142
#
# Urban
#               precision    recall  f1-score   support
#
#        False       0.81      0.88      0.84        77
#         True       0.88      0.80      0.84        81
#
#     accuracy                           0.84       158
#    macro avg       0.84      0.84      0.84       158
# weighted avg       0.84      0.84      0.84       158

# %% [markdown]
# # RFC & SVM

# %%
# train_1_x, train_1_y = preprocess(train[train['residence'] == 'Urban'])
# test_1_x, test_1_y = preprocess(test[test['residence'] == 'Urban'])

# train_2_x, train_2_y = preprocess(train[train['residence'] == 'Rural'])
# test_2_x, test_2_y = preprocess(test[test['residence'] == 'Rural'])


train_1_x, train_1_y = preprocess(train[:len(train) // 2])
test_1_x, test_1_y = preprocess(test[: len(test) // 2])

train_2_x, train_2_y = preprocess(train[len(train) //2 :])
test_2_x, test_2_y = preprocess(test[len(test) // 2:])

# %%
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier()
rfc.fit(train_1_x, train_1_y)
# Out:
# RandomForestClassifier()

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
train_2_x = scaler.fit_transform(train_2_x)
test_2_x = scaler.transform(test_2_x)

svm = SVC(probability=True)
svm.fit(train_2_x, train_2_y)
# Out:
# SVC(probability=True)

# %%
preds_1 = rfc.predict_proba(test_1_x)[:, 1]
preds_2 = svm.predict_proba(test_2_x)[:, 1]

# %%
def combine_preds(preds_1, preds_2):
    top_k = 50
    df = (
        pd.DataFrame({
            'pred': np.concatenate([preds_1, preds_2]),
            'model': [1] * len(preds_1) + [2] * len(preds_2)
            })
        .sort_values('pred', ascending=False)
        .iloc[:top_k]
    )
    print('frac of model 1:', (df['model'] == 1).mean())
    return df.style.background_gradient(subset='model', cmap='Pastel2')

# %%
from sklearn.calibration import CalibratedClassifierCV

# %%
calibrated_rfc = CalibratedClassifierCV(rfc, cv=5)
calibrated_rfc.fit(train_1_x, train_1_y)
calibrated_rfc_preds = calibrated_rfc.predict_proba(test_1_x)[:, 1]

# %%
calibrated_svm = CalibratedClassifierCV(svm, cv=5)
calibrated_svm.fit(train_2_x, train_2_y)
calibrated_svm_preds = calibrated_svm.predict_proba(test_2_x)[:, 1]

# %%
combine_preds(preds_1, preds_2)
# Out:
# frac of model 1: 0.24
# <style type="text/css">
# #T_61658_row0_col1, #T_61658_row17_col1, #T_61658_row18_col1, #T_61658_row26_col1, #T_61658_row27_col1, #T_61658_row28_col1, #T_61658_row37_col1, #T_61658_row38_col1, #T_61658_row41_col1, #T_61658_row42_col1, #T_61658_row48_col1, #T_61658_row49_col1 {
#   background-color: #b3e2cd;
#   color: #000000;
# }
# #T_61658_row1_col1, #T_61658_row2_col1, #T_61658_row3_col1, #T_61658_row4_col1, #T_61658_row5_col1, #T_61658_row6_col1, #T_61658_row7_col1, #T_61658_row8_col1, #T_61658_row9_col1, #T_61658_row10_col1, #T_61658_row11_col1, #T_61658_row12_col1, #T_61658_row13_col1, #T_61658_row14_col1, #T_61658_row15_col1, #T_61658_row16_col1, #T_61658_row19_col1, #T_61658_row20_col1, #T_61658_row21_col1, #T_61658_row22_col1, #T_61658_row23_col1, #T_61658_row24_col1, #T_61658_row25_col1, #T_61658_row29_col1, #T_61658_row30_col1, #T_61658_row31_col1, #T_61658_row32_col1, #T_61658_row33_col1, #T_61658_row34_col1, #T_61658_row35_col1, #T_61658_row36_col1, #T_61658_row39_col1, #T_61658_row40_col1, #T_61658_row43_col1, #T_61658_row44_col1, #T_61658_row45_col1, #T_61658_row46_col1, #T_61658_row47_col1 {
#   background-color: #cccccc;
#   color: #000000;
# }
# </style>
# <table id="T_61658">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_61658_level0_col0" class="col_heading level0 col0" >pred</th>
#       <th id="T_61658_level0_col1" class="col_heading level0 col1" >model</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_61658_level0_row0" class="row_heading level0 row0" >115</th>
#       <td id="T_61658_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_61658_row0_col1" class="data row0 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_61658_level0_row1" class="row_heading level0 row1" >265</th>
#       <td id="T_61658_row1_col0" class="data row1 col0" >0.999997</td>
#       <td id="T_61658_row1_col1" class="data row1 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_61658_level0_row2" class="row_heading level0 row2" >178</th>
#       <td id="T_61658_row2_col0" class="data row2 col0" >0.999994</td>
#       <td id="T_61658_row2_col1" class="data row2 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_61658_level0_row3" class="row_heading level0 row3" >165</th>
#       <td id="T_61658_row3_col0" class="data row3 col0" >0.999991</td>
#       <td id="T_61658_row3_col1" class="data row3 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_61658_level0_row4" class="row_heading level0 row4" >185</th>
#       <td id="T_61658_row4_col0" class="data row4 col0" >0.999983</td>
#       <td id="T_61658_row4_col1" class="data row4 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_61658_level0_row5" class="row_heading level0 row5" >156</th>
#       <td id="T_61658_row5_col0" class="data row5 col0" >0.996312</td>
#       <td id="T_61658_row5_col1" class="data row5 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_61658_level0_row6" class="row_heading level0 row6" >189</th>
#       <td id="T_61658_row6_col0" class="data row6 col0" >0.996181</td>
#       <td id="T_61658_row6_col1" class="data row6 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_61658_level0_row7" class="row_heading level0 row7" >280</th>
#       <td id="T_61658_row7_col0" class="data row7 col0" >0.995288</td>
#       <td id="T_61658_row7_col1" class="data row7 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_61658_level0_row8" class="row_heading level0 row8" >176</th>
#       <td id="T_61658_row8_col0" class="data row8 col0" >0.994937</td>
#       <td id="T_61658_row8_col1" class="data row8 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_61658_level0_row9" class="row_heading level0 row9" >249</th>
#       <td id="T_61658_row9_col0" class="data row9 col0" >0.994731</td>
#       <td id="T_61658_row9_col1" class="data row9 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_61658_level0_row10" class="row_heading level0 row10" >255</th>
#       <td id="T_61658_row10_col0" class="data row10 col0" >0.993525</td>
#       <td id="T_61658_row10_col1" class="data row10 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_61658_level0_row11" class="row_heading level0 row11" >150</th>
#       <td id="T_61658_row11_col0" class="data row11 col0" >0.993259</td>
#       <td id="T_61658_row11_col1" class="data row11 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_61658_level0_row12" class="row_heading level0 row12" >247</th>
#       <td id="T_61658_row12_col0" class="data row12 col0" >0.992398</td>
#       <td id="T_61658_row12_col1" class="data row12 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_61658_level0_row13" class="row_heading level0 row13" >281</th>
#       <td id="T_61658_row13_col0" class="data row13 col0" >0.991393</td>
#       <td id="T_61658_row13_col1" class="data row13 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_61658_level0_row14" class="row_heading level0 row14" >271</th>
#       <td id="T_61658_row14_col0" class="data row14 col0" >0.991350</td>
#       <td id="T_61658_row14_col1" class="data row14 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_61658_level0_row15" class="row_heading level0 row15" >224</th>
#       <td id="T_61658_row15_col0" class="data row15 col0" >0.991025</td>
#       <td id="T_61658_row15_col1" class="data row15 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_61658_level0_row16" class="row_heading level0 row16" >187</th>
#       <td id="T_61658_row16_col0" class="data row16 col0" >0.990070</td>
#       <td id="T_61658_row16_col1" class="data row16 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_61658_level0_row17" class="row_heading level0 row17" >123</th>
#       <td id="T_61658_row17_col0" class="data row17 col0" >0.990000</td>
#       <td id="T_61658_row17_col1" class="data row17 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_61658_level0_row18" class="row_heading level0 row18" >126</th>
#       <td id="T_61658_row18_col0" class="data row18 col0" >0.990000</td>
#       <td id="T_61658_row18_col1" class="data row18 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_61658_level0_row19" class="row_heading level0 row19" >283</th>
#       <td id="T_61658_row19_col0" class="data row19 col0" >0.987996</td>
#       <td id="T_61658_row19_col1" class="data row19 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_61658_level0_row20" class="row_heading level0 row20" >263</th>
#       <td id="T_61658_row20_col0" class="data row20 col0" >0.986213</td>
#       <td id="T_61658_row20_col1" class="data row20 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_61658_level0_row21" class="row_heading level0 row21" >294</th>
#       <td id="T_61658_row21_col0" class="data row21 col0" >0.984567</td>
#       <td id="T_61658_row21_col1" class="data row21 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_61658_level0_row22" class="row_heading level0 row22" >229</th>
#       <td id="T_61658_row22_col0" class="data row22 col0" >0.984191</td>
#       <td id="T_61658_row22_col1" class="data row22 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_61658_level0_row23" class="row_heading level0 row23" >287</th>
#       <td id="T_61658_row23_col0" class="data row23 col0" >0.983348</td>
#       <td id="T_61658_row23_col1" class="data row23 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_61658_level0_row24" class="row_heading level0 row24" >213</th>
#       <td id="T_61658_row24_col0" class="data row24 col0" >0.982773</td>
#       <td id="T_61658_row24_col1" class="data row24 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_61658_level0_row25" class="row_heading level0 row25" >206</th>
#       <td id="T_61658_row25_col0" class="data row25 col0" >0.982519</td>
#       <td id="T_61658_row25_col1" class="data row25 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_61658_level0_row26" class="row_heading level0 row26" >18</th>
#       <td id="T_61658_row26_col0" class="data row26 col0" >0.980000</td>
#       <td id="T_61658_row26_col1" class="data row26 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_61658_level0_row27" class="row_heading level0 row27" >127</th>
#       <td id="T_61658_row27_col0" class="data row27 col0" >0.980000</td>
#       <td id="T_61658_row27_col1" class="data row27 col1

# %%
combine_preds(calibrated_rfc_preds, calibrated_svm_preds)
# Out:
# frac of model 1: 0.42
# <style type="text/css">
# #T_425d8_row0_col1, #T_425d8_row1_col1, #T_425d8_row2_col1, #T_425d8_row3_col1, #T_425d8_row4_col1, #T_425d8_row5_col1, #T_425d8_row6_col1, #T_425d8_row7_col1, #T_425d8_row8_col1, #T_425d8_row9_col1, #T_425d8_row10_col1, #T_425d8_row11_col1, #T_425d8_row12_col1, #T_425d8_row13_col1, #T_425d8_row14_col1, #T_425d8_row16_col1, #T_425d8_row18_col1, #T_425d8_row21_col1, #T_425d8_row22_col1, #T_425d8_row25_col1, #T_425d8_row28_col1, #T_425d8_row30_col1, #T_425d8_row33_col1, #T_425d8_row36_col1, #T_425d8_row38_col1, #T_425d8_row44_col1, #T_425d8_row45_col1, #T_425d8_row46_col1, #T_425d8_row47_col1 {
#   background-color: #cccccc;
#   color: #000000;
# }
# #T_425d8_row15_col1, #T_425d8_row17_col1, #T_425d8_row19_col1, #T_425d8_row20_col1, #T_425d8_row23_col1, #T_425d8_row24_col1, #T_425d8_row26_col1, #T_425d8_row27_col1, #T_425d8_row29_col1, #T_425d8_row31_col1, #T_425d8_row32_col1, #T_425d8_row34_col1, #T_425d8_row35_col1, #T_425d8_row37_col1, #T_425d8_row39_col1, #T_425d8_row40_col1, #T_425d8_row41_col1, #T_425d8_row42_col1, #T_425d8_row43_col1, #T_425d8_row48_col1, #T_425d8_row49_col1 {
#   background-color: #b3e2cd;
#   color: #000000;
# }
# </style>
# <table id="T_425d8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_425d8_level0_col0" class="col_heading level0 col0" >pred</th>
#       <th id="T_425d8_level0_col1" class="col_heading level0 col1" >model</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_425d8_level0_row0" class="row_heading level0 row0" >265</th>
#       <td id="T_425d8_row0_col0" class="data row0 col0" >0.994987</td>
#       <td id="T_425d8_row0_col1" class="data row0 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_425d8_level0_row1" class="row_heading level0 row1" >178</th>
#       <td id="T_425d8_row1_col0" class="data row1 col0" >0.994508</td>
#       <td id="T_425d8_row1_col1" class="data row1 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_425d8_level0_row2" class="row_heading level0 row2" >165</th>
#       <td id="T_425d8_row2_col0" class="data row2 col0" >0.993268</td>
#       <td id="T_425d8_row2_col1" class="data row2 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_425d8_level0_row3" class="row_heading level0 row3" >185</th>
#       <td id="T_425d8_row3_col0" class="data row3 col0" >0.991341</td>
#       <td id="T_425d8_row3_col1" class="data row3 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_425d8_level0_row4" class="row_heading level0 row4" >156</th>
#       <td id="T_425d8_row4_col0" class="data row4 col0" >0.988198</td>
#       <td id="T_425d8_row4_col1" class="data row4 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_425d8_level0_row5" class="row_heading level0 row5" >189</th>
#       <td id="T_425d8_row5_col0" class="data row5 col0" >0.986590</td>
#       <td id="T_425d8_row5_col1" class="data row5 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_425d8_level0_row6" class="row_heading level0 row6" >249</th>
#       <td id="T_425d8_row6_col0" class="data row6 col0" >0.984888</td>
#       <td id="T_425d8_row6_col1" class="data row6 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_425d8_level0_row7" class="row_heading level0 row7" >280</th>
#       <td id="T_425d8_row7_col0" class="data row7 col0" >0.984295</td>
#       <td id="T_425d8_row7_col1" class="data row7 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_425d8_level0_row8" class="row_heading level0 row8" >150</th>
#       <td id="T_425d8_row8_col0" class="data row8 col0" >0.982444</td>
#       <td id="T_425d8_row8_col1" class="data row8 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_425d8_level0_row9" class="row_heading level0 row9" >176</th>
#       <td id="T_425d8_row9_col0" class="data row9 col0" >0.980201</td>
#       <td id="T_425d8_row9_col1" class="data row9 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_425d8_level0_row10" class="row_heading level0 row10" >255</th>
#       <td id="T_425d8_row10_col0" class="data row10 col0" >0.979741</td>
#       <td id="T_425d8_row10_col1" class="data row10 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_425d8_level0_row11" class="row_heading level0 row11" >271</th>
#       <td id="T_425d8_row11_col0" class="data row11 col0" >0.977809</td>
#       <td id="T_425d8_row11_col1" class="data row11 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_425d8_level0_row12" class="row_heading level0 row12" >281</th>
#       <td id="T_425d8_row12_col0" class="data row12 col0" >0.975645</td>
#       <td id="T_425d8_row12_col1" class="data row12 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_425d8_level0_row13" class="row_heading level0 row13" >224</th>
#       <td id="T_425d8_row13_col0" class="data row13 col0" >0.975541</td>
#       <td id="T_425d8_row13_col1" class="data row13 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_425d8_level0_row14" class="row_heading level0 row14" >247</th>
#       <td id="T_425d8_row14_col0" class="data row14 col0" >0.972679</td>
#       <td id="T_425d8_row14_col1" class="data row14 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_425d8_level0_row15" class="row_heading level0 row15" >127</th>
#       <td id="T_425d8_row15_col0" class="data row15 col0" >0.972643</td>
#       <td id="T_425d8_row15_col1" class="data row15 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_425d8_level0_row16" class="row_heading level0 row16" >283</th>
#       <td id="T_425d8_row16_col0" class="data row16 col0" >0.972365</td>
#       <td id="T_425d8_row16_col1" class="data row16 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_425d8_level0_row17" class="row_heading level0 row17" >49</th>
#       <td id="T_425d8_row17_col0" class="data row17 col0" >0.969730</td>
#       <td id="T_425d8_row17_col1" class="data row17 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_425d8_level0_row18" class="row_heading level0 row18" >263</th>
#       <td id="T_425d8_row18_col0" class="data row18 col0" >0.969675</td>
#       <td id="T_425d8_row18_col1" class="data row18 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_425d8_level0_row19" class="row_heading level0 row19" >18</th>
#       <td id="T_425d8_row19_col0" class="data row19 col0" >0.968423</td>
#       <td id="T_425d8_row19_col1" class="data row19 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_425d8_level0_row20" class="row_heading level0 row20" >115</th>
#       <td id="T_425d8_row20_col0" class="data row20 col0" >0.968411</td>
#       <td id="T_425d8_row20_col1" class="data row20 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_425d8_level0_row21" class="row_heading level0 row21" >187</th>
#       <td id="T_425d8_row21_col0" class="data row21 col0" >0.966164</td>
#       <td id="T_425d8_row21_col1" class="data row21 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_425d8_level0_row22" class="row_heading level0 row22" >229</th>
#       <td id="T_425d8_row22_col0" class="data row22 col0" >0.966092</td>
#       <td id="T_425d8_row22_col1" class="data row22 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_425d8_level0_row23" class="row_heading level0 row23" >126</th>
#       <td id="T_425d8_row23_col0" class="data row23 col0" >0.965306</td>
#       <td id="T_425d8_row23_col1" class="data row23 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_425d8_level0_row24" class="row_heading level0 row24" >123</th>
#       <td id="T_425d8_row24_col0" class="data row24 col0" >0.965098</td>
#       <td id="T_425d8_row24_col1" class="data row24 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_425d8_level0_row25" class="row_heading level0 row25" >294</th>
#       <td id="T_425d8_row25_col0" class="data row25 col0" >0.964662</td>
#       <td id="T_425d8_row25_col1" class="data row25 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_425d8_level0_row26" class="row_heading level0 row26" >84</th>
#       <td id="T_425d8_row26_col0" class="data row26 col0" >0.963975</td>
#       <td id="T_425d8_row26_col1" class="data row26 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_425d8_level0_row27" class="row_heading level0 row27" >143</th>
#       <td id="T_425d8_row27_col0" class="data row27 col0" >0.962433</td>
#       <td id="T_425d8_row27_col1" class="data row27 col1"
